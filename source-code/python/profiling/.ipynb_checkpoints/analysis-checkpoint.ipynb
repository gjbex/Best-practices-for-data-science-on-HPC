# %% [markdown]
# ## Requirements

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %load_ext viztracer

# %% [markdown]
# ## Data set

# %% [markdown]
# The data set consists of sensor data (temperature and pressure) measured over a three-month period.  The sensor is identified by an ID, and each measurement has status information about the sensor.

# %%
data = pd.read_csv(
    'sensor_data.csv',
    parse_dates=['datetime', ],
    dtype={
        'temperature': pd.Float32Dtype(),
        'pressure': pd.Float32Dtype(),
        'sensor_id': pd.UInt32Dtype(),
        'status': pd.CategoricalDtype(),
    },
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   datetime     datetime64[ns]
#  1   temperature  Float32
#  2   pressure     Float32
#  3   sensor_id    UInt32
#  4   status       category
# dtypes: Float32(2), UInt32(1), category(1), datetime64[ns](1)
# memory usage: 228.9 MB

# %% [markdown]
# ## Number of failures

# %% [markdown]
# If the sensor status is no `OK`, the data is not reliable. You can determine the number of failures per sensor easily.

# %%
# %%viztracer
# failures = data[['sensor_id', 'status']][data.status != 'OK'] \
#     .groupby('sensor_id') \
#     .count()
# Out:
# Button(description='VizTracer Report', style=ButtonStyle())

# %%
failures
# Out:
#            status
# sensor_id
# 1            1027
# 2             959
# 3            1011
# 4            1009
# 5            1029
# ...           ...
# 96           1033
# 97           1030
# 98            928
# 99            985
# 100          1004
#
# [100 rows x 1 columns]

# %%
sns.histplot(
    data=failures.index.repeat(failures.status),
    bins=data.sensor_id.unique().size,
    discrete=True
);

# %% [markdown]
# ## Measurements per day

# %% [markdown]
# How many measurements have been made per day by all sensors combined?

# %%
measure_count = data[['datetime', 'status']][data.status == 'OK'] \
    .groupby(data.datetime.dt.date).size() \
    .reset_index(name='meassurement_count')
measure_count.columns = ['date', 'measurement_count']

# %%
sns.lineplot(data=measure_count, x='date', y='measurement_count')
plt.xticks(rotation=55);

# %% [markdown]
# Compute the minimum, average, and maximum number of measurements over this time period.

# %%
print(f'number of measurements/day: {measure_count.measurement_count.min():.2f} '
      f'<= {measure_count.measurement_count.mean():.2f} '
      f'<= {measure_count.measurement_count.max():.2f}')
# Out:
# number of measurements/day: 109246.00 <= 110002.12 <= 110971.00

# %% [markdown]
# ## Temperatures

# %%
min_temperatures = data.groupby(data.datetime.dt.date).temperature.min()
mean_temperatures = data.groupby(data.datetime.dt.date).temperature.mean()
temperatures = pd.merge(min_temperatures, mean_temperatures, on='datetime', )
max_temperatures = data.groupby(data.datetime.dt.date).temperature.max()
temperatures = pd.merge(temperatures, max_temperatures, on='datetime')
temperatures.columns = ['min_temperature', 'mean_tempeature', 'max_temperature']

# %%
temperatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90 entries, 2025-01-01 to 2025-03-31
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   min_temperature  90 non-null     Float32
#  1   mean_tempeature  90 non-null     Float32
#  2   max_temperature  90 non-null     Float32
# dtypes: Float32(3)
# memory usage: 2.0+ KB

# %%
plt.figure(figsize=(12, 6))
plt.fill_between(temperatures.index, temperatures.min_temperature, temperatures.max_temperature, alpha=0.2)
sns.lineplot(data=temperatures, x=temperatures.index, y='mean_tempeature');

# %%
high_termperatures = data[['sensor_id', 'temperature']][data.temperature > 375.0] \
    .groupby('sensor_id') \
    .count()

# %%
sns.histplot(
    high_termperatures.index.repeat(high_termperatures.temperature),
    bins=10,
    discrete=True
);
